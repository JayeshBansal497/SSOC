# %% [markdown]
# <a href="https://colab.research.google.com/github/JayeshBansal497/2203A51207_DAA/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile sorting.cpp
# #include<iostream>
# using namespace std;
# int main()
# {
#     int arr[4],i=0;
#     do
#     {
#         cin>>arr[i];
#         if(arr[i]<arr[i-1])
#         {
#            arr[i]=arr[i]+arr[i-1];
#            arr[i-1]=arr[i]-arr[i-1];
#            arr[i]=arr[i]-arr[i-1];
#         }
#               i++;
#     }
#     while(i<4);
#     for(int i=0;i<4;i++)
#     cout<<arr[i]<<endl;
# }
# Out:
# Writing sorting.cpp

# %%
# !g++ sorting.cpp -o sort
# !./sort
# Out:
# 3
# 2
# 8
# 6
# 2
# 3
# 6
# 8
